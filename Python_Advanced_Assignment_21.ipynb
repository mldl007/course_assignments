# %% [markdown]
# Q1. What is a probability distribution, exactly? If the values are meant to be random, how can you
# predict them at all?
#
# Q2. Is there a distinction between true random numbers and pseudo-random numbers, if there is
# one? Why are the latter considered “good enough”?
#
# Q3. What are the two main factors that influence the behaviour of a &quot;normal&quot; probability distribution?
#
# Q4. Provide a real-life example of a normal distribution.
#
# Q5. In the short term, how can you expect a probability distribution to behave? What do you think will
# happen as the number of trials grows?
#
# Q6. What kind of object can be shuffled by using random.shuffle?
#
# Q7. Describe the math package&#39;s general categories of functions.
#
# Q8. What is the relationship between exponentiation and logarithms?
#
# Q9. What are the three logarithmic functions that Python supports?

# %% [markdown]
# <h4>Q1. What is a probability distribution, exactly? If the values are meant to be random, how can you
# predict them at all?

# %% [markdown]
# Probability distribution lists the probabilities of every value/outcome of a random variable

# %% [markdown]
# <h4>Q2. Is there a distinction between true random numbers and pseudo-random numbers, if there is
# one? Why are the latter considered “good enough”?

# %% [markdown]
# true random numbers are the ones that occur in real time. Pseudo random numbers are generated by a computer program based on a seed value. True random numbers are completely random, hence they are good.

# %% [markdown]
# <h4>Q3. What are the two main factors that influence the behaviour of a &quot;normal&quot; probability distribution?

# %% [markdown]
# mean and standard deviation

# %% [markdown]
# <h4>Q4. Provide a real-life example of a normal distribution.

# %% [markdown]
# height, weight, age

# %% [markdown]
# <h4>5. In the short term, how can you expect a probability distribution to behave? What do you think will
# happen as the number of trials grows?

# %% [markdown]
# As the trials grow the mean of probability distribution approches the true/population mean

# %% [markdown]
# <h4>Q6. What kind of object can be shuffled by using random.shuffle?

# %% [markdown]
# List of integers and numpy arrays

# %% [markdown]
# <h4>Q7. Describe the math package&#39;s general categories of functions.

# %% [markdown]
# sqrt, log, abs, sin, cos, tan, etc

# %% [markdown]
# <h4>Q8. What is the relationship between exponentiation and logarithms?

# %% [markdown]
# exponentiation is the reverse of logarithm and vice versa

# %% [markdown]
# <h4>Q9. What are the three logarithmic functions that Python supports?

# %% [markdown]
# loge, log2, log10
